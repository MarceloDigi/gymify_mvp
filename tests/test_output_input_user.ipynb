# %%
import pandas as pd
import numpy as np
import sys
import os
import warnings

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)

sys.path.append(os.path.abspath(os.path.join(os.path.dirname('__file__'), '..')))

import utils.data_loader as dl
import database.db_connector as connector

# %%
df = pd.read_csv(r"C:\Users\marcelo.cruz\gymify_mvp\test_validated_df.csv")

# %%
df.rename(columns={'Ejercicio':'exercise','Reps':'repreal','Peso':'weight','RIR':'rir'}, inplace=True)
range_sep = df['Rango'].str.split(' - ', expand=True).rename(columns={0: 'repmin', 1: 'repmax'}).astype(float)
df = pd.concat([df, range_sep], axis=1).drop(columns=['Rango'])
df['workload'] = df.repreal * df.weight
df['effective_set'] = np.where(df.rir <= 4, 1, 0)

# %%
df
# Out:
#         fecha                  exercise  repreal  weight  rir  repmin  repmax  \
# 0  2025-09-30  Scott machine bicep curl        5    45.0    2     6.0     8.0
# 1  2025-09-30  Scott machine bicep curl        5    45.0    3     6.0     8.0
# 2  2025-09-30  Scott machine bicep curl        5    45.0    4     6.0     8.0
# 3  2025-09-30  Scott machine bicep curl        5    45.0    1     6.0     8.0
# 4  2025-09-30     Incline barbell press        1   135.0    2    78.5     NaN
# 5  2025-09-30     Incline barbell press        2   134.0    2    81.0     NaN
#
#    workload  effective_set
# 0     225.0              1
# 1     225.0              1
# 2     225.0              1
# 3     225.0              1
# 4     135.0              1
# 5     268.0              1

# %%
workouts = connector.query_to_dataframe("SELECT * FROM workouts")
# Out:
# 🔍 Conexión detectada: mysql+pymysql://root:KwsvOvoasXFjfwKyItZXqpmQTwskoqTG@interchange.proxy.rlwy.net:44580/railway

# %%
workouts
# Out:
#        id_set   routine      fecha                 exercise  repmin  repmax  \
# 0           1   Upper I 2023-01-16      Low cable crossover     6.0    12.0
# 1           2   Upper I 2023-01-16      Low cable crossover     6.0    12.0
# 2           3   Upper I 2023-01-16      Low cable crossover     6.0    12.0
# 3           4   Upper I 2023-01-16                 Chin-ups     1.0     NaN
# 4           5   Upper I 2023-01-16                 Chin-ups     5.0     NaN
# ...       ...       ...        ...                      ...     ...     ...
# 10078   10079  Upper II 2025-05-01   Dumbbell lateral raise    -1.0     NaN
# 10079   10080  Upper II 2025-05-01  Unilateral french press    10.0    15.0
# 10080   10081  Upper II 2025-05-01  Unilateral french press    10.0    15.0
# 10081   10082  Upper II 2025-05-01  Unilateral french press    10.0    15.0
# 10082   10083  Upper II 2025-05-01  Unilateral french press    10.0    15.0
#
# ...
